# %% [markdown]
# <a href="https://colab.research.google.com/github/s26g3108jv-netizen/literacy/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !openssl genrsa -out kei-private.pem 2048
# !openssl rsa -in kei-private.pem -pubout -out kei-public.pem

# %%
# !printf "こんにちは\n" > report

# %%
# !openssl pkeyutl -encrypt -pubin -inkey kei-public.pem -in report -out report-secret
# !base64 report-secret
