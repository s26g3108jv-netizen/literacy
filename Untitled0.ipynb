# %% [markdown]
# <a href="https://colab.research.google.com/github/s26g3108jv-netizen/literacy/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !openssl genrsa -out kei-private.pem 2048
# !openssl rsa -in kei-private.pem -pubout -out kei-public.pem
# Out:
# writing RSA key

# %%
# !printf "26G3108\n" > report

# %%
# !openssl pkeyutl -encrypt -pubin -inkey kei-public.pem -in report -out report-secret
# !base64 report-secret
# Out:
# Gnxm62/ZF4siCa4lZ8Ok2cRwPf4u9faakyEdg54PJGAr+faeZSOb58MrqXG/XWSvTlLf7P5xe0m6
# WFucBqWMATTPhKsVavH5cQGijd6qm47/+uq+1jgB8dAzoBi3Kj8gxgJik0cDtBisse+Ci7NeCby6
# WjwfS8UBYSPMSL+5yRM/klpyVlJ0qgjb0mdQWwfV1oeuRgDH81aKqWd/sM7v1TO5xzfdNsLHioc/
# hL11Yn4v51DWvGeiSONH2aUmfTeLI271Rhzjj4h5MSyI2i7ZVtkmMfqtsMh+V64y4uxVs1AUs8aX
# raFMvSrwQBBEs5OcsPPVqlSY2flInZcepFv89A==

# %%
# !openssl pkeyutl -decrypt -inkey kei-private.pem -in report-secret
# Out:
# 26G3108
